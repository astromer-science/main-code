# %% [markdown]
# # Creating records
# ## Pipeline 2.0
# ##### ASTROMER dev team
#
# *Feb 27 2024*

# %%
from utils import set_working_directory_up_two_levels
set_working_directory_up_two_levels()

# %%
import matplotlib.pyplot as plt
import polars as pl
import pandas as pd
import numpy as np
import os

from src.data.record import DataPipeline, create_config_toml

os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-12-02 11:20:53.725166: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-02 11:20:53.725212: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-02 11:20:53.725237: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-02 11:20:53.732754: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Describing raw data before record creation

# %%
metadata = pl.read_parquet('./data/praw/alcock/metadata.parquet')
single_md = metadata.filter(pl.col('shard') == 0)
observations = pl.read_parquet('./data/praw/alcock/light_curves/shard_000.parquet')
observations.columns
# Out:
# ['mjd', 'mag', 'errmag', 'newID', '__index_level_0__']

# %%
fig, axes = plt.subplots(1, 1)
curve = observations.filter(pl.col('newID') == 1)
axes.plot(curve['mjd'], curve['mag'], marker='.', color='k')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 3), gridspec_kw={'wspace':0.4}, dpi=100)
axes[0].boxplot(observations['mjd'])
axes[0].set_title('Time (MJD)')
axes[1].boxplot(observations['mag'])
axes[1].set_title('Magnitude')
axes[2].boxplot(observations['errmag'])
axes[2].set_title('Magnitude STD')
plt.show()

# %% [markdown]
# ## Creating records

# %% [markdown]
# In order to specify record features you have to create a `config.toml` file. A template of the config file is as following:
#
# ```
# [id_column]
#     value = 'newID'
#     dtype = 'integer'
#
# [target]
#     value = './data/records_parquet/alcock'
#     dtype = 'string'
#
# [context_features]
# 	value = ['ID', 'Label', 'Class', 'Band']
# 	dtypes = ['string', 'integer', 'string', 'integer']
#
# [sequential_features]
# 	value = ['mjd', 'mag', 'err']
# 	dtypes = ['float', 'float', 'float']
# ```

# %% [markdown]
# where `newID` is an integer-based id used for efficently filter light curves. `general.target` specifies the target directory where tf.records will be stored. `context_features` are the columns from the `metadata.csv` containing static information of the light curve while `sequential_features` are the time-depended features. The name of the columns both for context and sequential features should match the names of the column in their corresponding tables (`metadata.csv` and `lightcurves/shard_xxx.parquet`).

# %%
METAPATH = './data/praw/ogle/metadata.parquet'
OBSPATH  = './data/praw/ogle/light_curves/'

# %%
metadata = pd.read_parquet(METAPATH)

# %%
metadata.sample(1)
# Out:
#                          ID  Class                     Path     N  Band  \
# 282009  OGLE-BLG-LPV-146917  OSARG  OGLE-BLG-LPV-146917.dat  1313   1.0
#
#          sset   newID                                            path  Label  \
# 282009  train  282009  data/raw_data/ogle/LCs/OGLE-BLG-LPV-146917.dat      4
#
#         shard
# 282009     14

# %% [markdown]
# use `create_config_toml` to easily create a config file

# %%
create_config_toml(parquet_id='newID',
                   target='./data/precords/alcock/',
                   context_features=['ID', 'Class', 'N', 'Band', 'Label', 'shard'],
                   sequential_features=['mjd', 'mag', 'errmag'],
                   context_dtypes=['string', 'string', 'integer', 'integer', 'integer', 'integer'],
                   sequential_dtypes=['float', 'float', 'float'])
# Out:
# [INFO] Toml file succefully created at: ./data/precords/alcock/

# %%
metadata.sample()
# Out:
#                      ID Class                  Path    N  Band   sset  newID  \
# 60274  lmc_sc3_i_225502   std  lmc_sc3_i_225502.dat  366   1.0  train  60274
#
#                                               path  Label  shard
# 60274  data/raw_data/ogle/LCs/lmc_sc3_i_225502.dat     10      3

# %% [markdown]
# ### Using DataPipeline class

# %% [markdown]
# We first define our train-test-validation subsets using the `ID`

# %%
test_metadata = metadata.sample(frac=0.25)
rest = metadata[~metadata['newID'].isin(test_metadata['newID'])]
assert test_metadata['newID'].isin(rest['newID']).sum() == 0 # check if there are duplicated indices

validation_metadata = rest.sample(frac=0.25)
train_metadata = rest[~rest['newID'].isin(validation_metadata['newID'])]
assert train_metadata['newID'].isin(validation_metadata['newID']).sum() == 0 # check if there are duplicated indices

# %% [markdown]
# it is important to define a new column in metadata with the `subset_k` tag, where `k` is the number of the fold. You can create as many folds as you want while creating more `subset` columns.

# %%
train_metadata['subset_0'] = ['train']*train_metadata.shape[0]
validation_metadata['subset_0'] = ['validation']*validation_metadata.shape[0]
test_metadata['subset_0'] = ['test']*test_metadata.shape[0]
# Out:
# /tmp/ipykernel_3161754/2469551710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_metadata['subset_0'] = ['train']*train_metadata.shape[0]

# %% [markdown]
# After having all defined we create our final metadata:

# %%
final_metadata = pd.concat([train_metadata, validation_metadata, test_metadata])
final_metadata['subset_0'].unique()
# Out:
# array(['train', 'validation', 'test'], dtype=object)

# %% [markdown]
# once everything is ready in our metadata csv we can start using the `DataPipeline` class

# %%
# Create an instance of DataPipeline
config_path = './data/precords/alcock/config.toml'

pipeline = DataPipeline(metadata=final_metadata,
                        config_path=config_path)
# Out:
# [INFO] 393103 samples loaded

# %%
pipeline.metadata.sample(4)
# Out:
#                           ID  Class                      Path     N  Band  \
# 237188   OGLE-BLG-LPV-168245  OSARG   OGLE-BLG-LPV-168245.dat  1683   1.0
# 217956  OGLE-BLG-RRLYR-08479   RRab  OGLE-BLG-RRLYR-08479.dat   330   1.0
# 62800       lmc_sc7_i_303828    std      lmc_sc7_i_303828.dat   377   1.0
# 288616   OGLE-BLG-LPV-086168  OSARG   OGLE-BLG-LPV-086168.dat   823   1.0
#
#          sset   newID                                             path  Label  \
# 237188  train  237188   data/raw_data/ogle/LCs/OGLE-BLG-LPV-168245.dat      4
# 217956  train  217956  data/raw_data/ogle/LCs/OGLE-BLG-RRLYR-08479.dat      5
# 62800   train   62800      data/raw_data/ogle/LCs/lmc_sc7_i_303828.dat     10
# 288616  train  288616   data/raw_data/ogle/LCs/OGLE-BLG-LPV-086168.dat      4
#
#         shard subset_0
# 237188     11     test
# 217956     10    train
# 62800       3    train
# 288616     14     test

# %%
for k in range(1):
    train_subset = pipeline.metadata[pipeline.metadata[f'subset_{k}'] == 'train']
    val_subset   = pipeline.metadata[pipeline.metadata[f'subset_{k}'] == 'validation']
    test_subset  = pipeline.metadata[pipeline.metadata[f'subset_{k}'] == 'test']

    print(train_subset.shape, val_subset.shape, test_subset.shape)

    print('test in train?: ', test_subset['ID'].isin(train_subset['ID']).all(),'\n',
          'val in train?: ', val_subset['ID'].isin(train_subset['ID']).all(),'\n',
          'val in test?: ', val_subset['ID'].isin(test_subset['ID']).all())
# Out:
# (221120, 11) (73707, 11) (98276, 11)
# test in train?:  False
#  val in train?:  False
#  val in test?:  False

# %% [markdown]
# Now it is **time to the pipeline**

# %%
pipeline.context_features, pipeline.context_features_dtype
# Out:
# (['ID', 'Class', 'N', 'Band', 'Label', 'shard'],
#  ['string', 'string', 'integer', 'integer', 'integer', 'integer'])

# %%
# %%time
var = pipeline.run(observations_path=OBSPATH, 
                   n_jobs=8,
                   elements_per_shard=20000)
# Out:
# 2024-06-25 05:00:00,480 - INFO - Starting DataPipeline operations
# [INFO] Reading parquet
# [INFO] Light curves loaded
# Processing fold 1/1 - train:   0%|                                                                                                          | 0/3 [00:00<?, ?it/s]2024-06-25 05:01:08.986890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.987231: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.987517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.987799: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.990437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.990731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.991004: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.991274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.991542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.991811: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.992082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.992463: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:08.993170: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 05:01:09.533256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.533584: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.533865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.534141: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.534426: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.534696: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.534966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.535233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.535504: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.535776: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.536043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:09.536444: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.303082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.303422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.303708: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.303990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.304274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.304544: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.304802: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.305061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.305349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.305611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 732 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2024-06-25 05:01:11.305995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.306240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 732 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:82:00.0, compute capability: 8.6
# 2024-06-25 05:01:11.306546: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.306788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22329 MB memory:  -> device: 2, name: NVIDIA RTX A5000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2024-06-25 05:01:11.306991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-25 05:01:11.307231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22329 MB memory:  -> device: 3, name: NVIDIA RTX A5000, pci bus id: 0000:c2:00.0, compute capability: 8.6
# Processing fold 1/1 - test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [04:23<00:00, 87.78s/it]
# 2024-06-25 05:05:31,495 - INFO - Finished execution of DataPipeline operations
# CPU times: user 35min 34s, sys: 4min 14s, total: 39min 49s
# Wall time: 5min 31s

# %% [markdown]
# ### Customize what happens within the preprocess function

# %% [markdown]
# You must keep the same parameters of the method i.e., `row, context_features, sequential_features`.
#
# Also the **output** should be tuple containing the lightcurve (`pd.DataFrame`) and the context values (`dict`)
#
#
# To modify the `process_sample` method we need to create a new class (`MyPipeline`) that inherits from `DataPipeline`

# %% [markdown]
# polars functions: https://docs.pola.rs/api/python/stable/reference/expressions/functions.html

# %%
import polars as pl
class MyPipeline(DataPipeline):
    def lightcurve_step(self, inputs):
        """
        Preprocessing applied to each light curve separately
        """
        # First feature is time
        inputs = inputs.sort(self.sequential_features[0], descending=True) 
        p99 = inputs.quantile(0.95, 'nearest')
        p01 = inputs.quantile(0.05, 'nearest')
        inputs = inputs.filter(pl.col('mag') < p99['mag'])
        inputs = inputs.filter(pl.col('mag') > p01['mag'])
        return inputs

    def observations_step(self):
        """
        Preprocessing applied to all observations. Filter only
        """
        fn_0 = pl.col('errmag') > 0
        fn_1 = pl.col('errmag') < 1.
        fn_2 = pl.col('errmag') < pl.col('mag').abs()
        return fn_0 & fn_1 & fn_2

# %% [markdown]
# Next steps are the same as using the original `DataPipeline` class

# %%
custom_pipeline = MyPipeline(metadata=final_metadata,
                             config_path=config_path)
# Out:
# [INFO] 393103 samples loaded

# %%
# %%time
var = custom_pipeline.run(observations_path=OBSPATH, 
                          n_jobs=10,
                          elements_per_shard=20000)
# Out:
# 2024-06-25 05:06:29,511 - INFO - Starting DataPipeline operations
# [INFO] Reading parquet
# [INFO] Light curves loaded
# Processing fold 1/1 - test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [04:03<00:00, 81.22s/it]
# 2024-06-25 05:14:32,142 - INFO - Finished execution of DataPipeline operations
# CPU times: user 2h 4min 22s, sys: 11min 24s, total: 2h 15min 46s
# Wall time: 8min 2s

# %% [markdown]
# # Reading

# %%
import tensorflow as tf
from src.data.loaders import get_loader
from src.data.zero import pretraining_pipeline # astromer v0
from presentation.pipelines.steps.load_data import build_loader
from src.layers.input import AddMSKToken
import glob
import os

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
root = './data/records/macho/full/fold_0/'
window_size = 10
probed_frac = .3
random_frac = 0.1
same_frac = 0.1

params = {
    'norm': 'zero-mean',
    'probed': probed_frac,
    'rs': random_frac,
    'same': same_frac,
    'window_size': window_size,
    'arch': 'base',
}

# %%
loaders = build_loader(data_path=root, 
                       params=params,
                       batch_size=16,
                       debug=False,
                       sampling=True,
                       repeat=0,
                       return_test=True,
                       )
# Out:
# [INFO] String based loader
# [INFO] Probed: 0.30 Random: 0.10 Same: 0.10
# [INFO] Normalization:  zero-mean
# [INFO] Sampling random windows
# [INFO] Probed: 0.30 Random: 0.10 Same: 0.10
# [INFO] Normalization:  zero-mean
# [INFO] Sampling random windows
# [INFO] Probed: 0.30 Random: 0.10 Same: 0.10
# [INFO] Normalization:  zero-mean

# %%
dataset = loaders['train']

msk_layer = AddMSKToken(trainable=True, 
                        window_size=window_size, 
                        on=['input'], 
                        name='msk_token')

# %%
plt.figure(figsize=(15, 5))
for x, y in dataset.take(1):
    print(y.keys())
    plt.title(y['lcid'][0].numpy())
    inp_with_msk = msk_layer(x)
    
    xinp = tf.boolean_mask(x['input'][0], 1.-x['mask_in'][0])
    tinp = tf.boolean_mask(x['times'][0], 1.-x['mask_in'][0])

    xinp_2 = tf.boolean_mask(x['input'][0], y['mask_out'][0])
    tinp_2 = tf.boolean_mask(x['times'][0], y['mask_out'][0])   

    
    plt.plot(tinp, xinp, marker='o', markersize=14, linestyle='', color='darkgreen', label='Visible', alpha=0.4)
    plt.plot(x['times'][0], y['target'][0], marker='', linestyle='-', color='k', label='Target')    
    plt.plot(inp_with_msk['times'][0], inp_with_msk['input'][0], marker='s', linestyle='', color='blue', label='Input')
    plt.plot(tinp_2, xinp_2, marker='x', markersize=10, linestyle='', color='darkred', label='Probed')  
     
    plt.legend()
plt.show()
# Out:
# dict_keys(['target', 'w_error', 'mask_out', 'lcid'])

# %%
df_objects = pd.read_csv('./data/shared/records/atlas/fold_0/atlas/objects.csv')

# %%
plt.figure(figsize=(5, 3), dpi=300)
plt.bar(df_objects['label'], df_objects['size'], color='#922b21')
for k, val in enumerate(df_objects['size']):
    plt.text(k-0.3, val+val*1/20, '{:.0f}'.format(val), color='k')
plt.ylim(0, df_objects['size'].max()+50000)
plt.savefig('./presentation/figures/classification/atlas_dist.png', format='png')
plt.show()

# %%
plt.figure(figsize=(5, 3), dpi=300)
plt.bar(df_objects['label'], df_objects['size'], color='#922b21')
for k, val in enumerate(df_objects['size']):
    plt.text(k-0.25, val+val*1/20, '{:.0f}'.format(val), color='k')
plt.ylim(0, df_objects['size'].max()+1000)
plt.savefig('./presentation/figures/classification/alcock_dist.png', format='png')
plt.show()
# Out:
#    label  size
# 0  Cep_0  1082
# 1  Cep_1   583
# 2     EC  6724
# 3    LPV  2946
# 4   RRab  7297
# 5    RRc  1662

# %%
df_objects
# Out:
#    label    size
# 0     CB   80218
# 1     DB   28767
# 2   Mira    7370
# 3  Other  281254
# 4  Pulse   25021
