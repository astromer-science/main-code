# %%
from utils import set_working_directory_up_two_levels
set_working_directory_up_two_levels()

# %%
import matplotlib.pyplot as plt 

import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import os 

from glob import glob

from sklearn.metrics import confusion_matrix
import matplotlib.patheffects as PathEffects

from tqdm import tqdm
from presentation.pipelines.steps.model_design import load_pt_model, build_classifier 

from src.metrics.visualize import compute_cm_stats
from src.plot.conmatrix import plot_confusion_matrices
from src.plot.general import save_plot

pd.options.mode.chained_assignment = None  # default='warn'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1" # GPU number -1 off by default

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results_directory = './presentation/results/v2'
dataset_name = 'alcock'

# %%
stats_alcock = compute_cm_stats(results_directory, dataname='alcock', spc_list=[20, 100, 500])
stats_atlas = compute_cm_stats(results_directory, dataname='atlas', spc_list=[20, 100, 500])

# %%
fig_alcock, axes = plot_confusion_matrices(stats_alcock, 'alcock')

# %%
fig_atlas, axes = plot_confusion_matrices(stats_atlas, 'atlas')

# %%
save_plot(fig_alcock, path='./presentation/figures/classification/alcock_cm.pdf')
save_plot(fig_atlas, path='./presentation/figures/classification/atlas_cm.pdf')
# Out:
# Plot saved successfully at: ./presentation/figures/classification/alcock_cm.pdf
# Plot saved successfully at: ./presentation/figures/classification/atlas_cm.pdf
