# %%
from utils import set_working_directory_up_two_levels
set_working_directory_up_two_levels()

# %%
import matplotlib.pyplot as plt
import polars as pl
import numpy as np
import pickle
import pandas as pd
import os
import random
import seaborn as sns

from tqdm import tqdm
from src.data.loaders import get_loader
from joblib import Parallel, delayed
from functools import partial

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-01-25 00:48:57.988509: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 00:48:57.988572: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 00:48:57.988602: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 00:48:57.997694: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## MACHO stats

# %%
def get_stat(path, on='mag', window=100):
    observations = pd.read_parquet(path)
    observations = observations[(observations['errmag']>0) & (observations['errmag']<1)]
    
    if on == 'mjd':
        observations = observations.groupby('newID').diff().dropna()
        
    observations = observations.sort_values(on)
    observations = observations[on].rolling(window=window, step=window).mean()
    return observations.dropna().tolist()

def calculate_stat(root, on='mag', window=1000, njobs=4):
    lc_paths = os.listdir(root)
    preloaded = partial(get_stat, on=on, window=window)
    var = Parallel(n_jobs=njobs, backend='threading')
    results = var(delayed(preloaded)(os.path.join(root, p)) for p in lc_paths )
    flattened = [item for sublist in results for item in sublist]
    return flattened

# %%
# %%time
root = './data/raw_parquet/macho/light_curves/'
macho_mjd = calculate_stat(root, on='mjd', njobs=16)
macho_mjd = np.array(macho_mjd)[np.array(macho_mjd)>0]

macho_mag = calculate_stat(root, on='mag', njobs=16)
# Out:
# CPU times: user 18min 32s, sys: 4min 21s, total: 22min 54s
# Wall time: 1min 32s

# %%
# %%time
root = './data/raw_parquet/alcock/light_curves/'
other_mjd = calculate_stat(root, on='mjd', njobs=16)
other_mjd = np.array(other_mjd)[np.array(other_mjd)>0]

other_mag = calculate_stat(root, on='mag', njobs=16)
# Out:
# CPU times: user 7.14 s, sys: 1.98 s, total: 9.11 s
# Wall time: 6.92 s

# %%
# %%time
root = './data/raw_parquet/atlas/light_curves/'
atlas_mjd = calculate_stat(root, on='mjd', njobs=16)
atlas_mjd = np.array(atlas_mjd)[np.array(atlas_mjd)>0]

atlas_mag = calculate_stat(root, on='mag', njobs=16)
# Out:
# CPU times: user 5min 35s, sys: 1min 10s, total: 6min 45s
# Wall time: 29.9 s

# %%
def cut_tails(vector):
    p95 = np.percentile(vector, q=80)
    p5 = np.percentile(vector, q=10)
    vector = vector[vector<=p95]
    vector = vector[vector>=p5]
    return vector

# %%
# with open('./data/shared/records/bigmacho/bigmacho_magnitudes.pickle', 'rb') as handle:
#     bighmacho_mag = pickle.load(handle)

# indices = np.arange(len(bighmacho_mag))
# np.random.shuffle(indices)
# indices = indices[:len(macho_mag)*2]
# bighmacho_mag = np.array(bighmacho_mag)[indices]
# len(bighmacho_mag)

# %%
def reduce_vector(vector, n=100):
    indices = np.arange(len(vector))
    np.random.shuffle(indices)
    vector = np.array(vector)[:100]
    return vector

# %%
# %%time
fig, ax = plt.subplots(1, 1, dpi=300, figsize=(5,3))
sns.boxplot(data=[other_mjd, 
                  macho_mjd, 
                  atlas_mjd], 
            ax=ax, 
            showfliers=False,
            color='#aa91c9')

ax.set_yscale('log')
ax.set_ylabel(r'$\Delta t$ (MJD)')
ax.set_xticklabels(['Alcock', 'MACHO', 'ATLAS'])

fig.savefig('./presentation/figures/mjd_datasets.pdf', 
            format='pdf', 
            bbox_inches='tight')
plt.show()
# Out:
# 2025-01-25 01:03:22,933 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-25 01:03:24,564 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <timed exec>:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# CPU times: user 5.09 s, sys: 634 ms, total: 5.72 s
# Wall time: 5.13 s

# %%
# %%time
plt.figure(figsize=(4, 3), dpi=300)
h2 = plt.hist(other_mag, bins=100,  density=True, label='Alcock', facecolor='k', edgecolor='k', histtype='step', hatch='\\')
h1 = plt.hist(macho_mag, bins=100,  density=True, label='MACHO', facecolor='#98d0e3')
h3 = plt.hist(atlas_mag, bins=100,  density=True, label='ATLAS', histtype='step', color='#aa91c9')
plt.legend()
plt.xlabel('Magnitudes')
plt.ylabel('Density')
# plt.yscale('log')
plt.savefig('./presentation/figures/magnitude_datasets.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# CPU times: user 4.72 s, sys: 631 ms, total: 5.35 s
# Wall time: 4.84 s

# %%
scan2 = pl.scan_parquet('./data/raw_parquet/alcock/light_curves/*.parquet')
